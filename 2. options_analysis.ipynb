# %% [markdown]
# ## Import.

# %%
from avengers import Jarvis, Vision

# %% [markdown]
# ## Data load.

# %% [markdown]
# Here we need Vision class object for long period implied volatility analysis.
#
# Let's start with RTS object. At this case it includes both futures and options data. Takes time.

# %%
# %%time
RTS = Vision('RTS')
# Out:
# CPU times: user 2min 6s, sys: 5.02 s, total: 2min 11s
# Wall time: 2min 19s

# %% [markdown]
# RTS contains 20 Jarvis objects for 5 years from 2017 to 2021.

# %%
RTS.objects_dict
# Out:
# {'RTS-3.17': <avengers.Jarvis at 0x7faf9ae07310>,
#  'RTS-6.17': <avengers.Jarvis at 0x7faf9ae07340>,
#  'RTS-9.17': <avengers.Jarvis at 0x7fafaa142be0>,
#  'RTS-12.17': <avengers.Jarvis at 0x7fafaa14cc10>,
#  'RTS-3.18': <avengers.Jarvis at 0x7fafaa189100>,
#  'RTS-6.18': <avengers.Jarvis at 0x7fafaa198070>,
#  'RTS-9.18': <avengers.Jarvis at 0x7fafaa18e0a0>,
#  'RTS-12.18': <avengers.Jarvis at 0x7fafaa197df0>,
#  'RTS-3.19': <avengers.Jarvis at 0x7fafaa75b6d0>,
#  'RTS-6.19': <avengers.Jarvis at 0x7fafaa7695e0>,
#  'RTS-9.19': <avengers.Jarvis at 0x7fafaa7779a0>,
#  'RTS-12.19': <avengers.Jarvis at 0x7fafaa763280>,
#  'RTS-3.20': <avengers.Jarvis at 0x7fafaa7834c0>,
#  'RTS-6.20': <avengers.Jarvis at 0x7fafaa7850d0>,
#  'RTS-9.20': <avengers.Jarvis at 0x7fafaa764130>,
#  'RTS-12.20': <avengers.Jarvis at 0x7fafaa8fba60>,
#  'RTS-3.21': <avengers.Jarvis at 0x7fafaa900610>,
#  'RTS-6.21': <avengers.Jarvis at 0x7fafaa906f10>,
#  'RTS-9.21': <avengers.Jarvis at 0x7fafaa90cc10>,
# ...

# %% [markdown]
# RTS futures adjusted prices plot is below.

# %%
RTS.plot()

# %%
RTS.iv_plot()

# %%
RTS.iv_hist()

# %%
Si = Vision('Si')
# Out:
# no sort opt df
# no sort opt df
# no sort opt df
# no sort opt df
# no sort opt df

# %%
Si.iv_plot()

# %%
Si.iv_hist()

# %% [markdown]
# It's amasing, right? ; )
